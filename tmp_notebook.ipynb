# %%
import pandas as pd

# %%
df = pd.read_json('/home/jovyan/medvedev/NeMo-Skills/nemo_skills/math-contamination-retrieved.jsonl', lines=True)

# %%
df[['problem', 'similar_items', 'similarity_scores']]
# Out:
#                                                 problem  \
# 0     Task: Repair the mouse in the office.\nConditi...
# 1     Task: Replace the basketball hoop in the gym w...
# 2     Task: Retrieve the projector from the cupboard...
# 3     Task: Bring the snowboard boots from the pantr...
# 4     Task: Scan the barcodes on the sugar packs.\nC...
# ...                                                 ...
# 2146  Task: Destroy the photos in the shredder in th...
# 2147  Task: Remove the magazine from the table.\nCon...
# 2148  Task: Find the recipe for a cake in the recipe...
# 2149  Task: Fix the loose skirting board in the bedr...
# 2150  Task: Set up the alarm clock on the bedside ta...
#
#                                           similar_items  \
# 0     [Task: Repair the mouse in the office.\nCondit...
# 1     [Task: Move the basketball hoop from the worko...
# 2     [Task: Retrieve a new projector from the cabin...
# 3     [Task: Retrieve snowboard boots from the cabin...
# ...

# %%
pd.set_option('display.max_colwidth', None)  # Set to None to display all text in each column

# %%
df[['problem', 'similar_items', 'similarity_scores']].head(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           problem  \
# ...
